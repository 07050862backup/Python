# %% [markdown]
# ### EX 1: 試實現一個python程式，它能將使用者所輸入的一個文字字串之首尾兩個字元互換再輸出。

# %% [markdown]
# 例如:
#
# 輸入: apple
#
# 輸出: eppla
#
# 輸入: 12345
#
# 輸出: 52341

# %%
str1 = str(input("請輸入字串:"))

str2 = str1[::-1] #將str1逆序輸出

print('新字串為: ',str2[0]+str1[1:-1]+str1[0])
# Out:
# 請輸入字串:12345
# 新字串為:  52341

# %% [markdown]
# ### EX 2: 試實現一個python程式，它能產生下面的圖案。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(1, 10):
    print('' + str(i)*i)
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999

# %% [markdown]
# ### EX 3: 試利用str.replace()這個內建函式的功能，移除輸入字串裡的空格。

# %% [markdown]
# 例如:
#
# 輸入: embedded system, 輸出: embeddedsystem
#
# 輸入: Python String Exercise, 輸出: PythonStringExercise

# %%
str1 = str(input("請輸入字串:"))

str2 = str1.replace(' ', '')

print(str2)
# Out:
# 請輸入字串:embedded system
# embeddedsystem

# %% [markdown]
# ### EX 4: 試利用str.rsplit()函式的功能，將輸入的字串以逗號為分割點，轉換成list。

# %% [markdown]
# 例如:
#
# 輸入: The World of Peter, Jane, and Thomas Jefferson
#
# 輸出: ['The World of Peter', ' Jane', ' and Thomas Jefferson']

# %%
str1 = str(input("請輸入字串:"))

str2 = str1.rsplit(',')

print(str2)
# Out:
# 請輸入字串:The World of Peter, Jane, and Thomas Jefferson
# ['The World of Peter', ' Jane', ' and Thomas Jefferson']
