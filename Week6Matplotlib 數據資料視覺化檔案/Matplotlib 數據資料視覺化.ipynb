# %% [markdown]
# # Matplotlib繪圖

# %% [markdown]
# matplotlib是python最著名的繪圖套件，它的與操作方式與matlab相當相似，使用者可以很方便的利用本套件來達成各種繪圖功能。

# %% [markdown]
# ##  Matplotlib 模組的使用

# %% [markdown]
# Matploib 模組在使用前必須先安裝，(Anaconda中預設已安裝)，語法如下:

# %%
pip install matplotlib

# %% [markdown]
# 使用Matplotib繪圖首先要載入Matplotlb模組由於大部分繪圖功能是在
# 「matplotlib.pyplot中,因此通常會在載入「matplotlib.pyplot」時設定一個簡短的
# 別名,方便往後輸入,例如將別名取為「plt」:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 繪製折線圖 : plot

# %% [markdown]
# ## 1-1. 繪製折線圖

# %% [markdown]
# 折線圖是以plot函數繪製,語法為:

# %% [markdown]
# plt.plot([x座標串列],y座標串列[,其他參數])

# %% [markdown]
# 此處我們介紹最簡單的二維折線圖繪製，設有一個串列Y = [1,2,3,4]，我們可以按下面程式碼畫出二維折線圖：

# %% [markdown]
# Y軸指定為[1,2,3,4]，但未輸入X軸的串列，系統會自動設定X軸的輸入參數為[0,1,2,3]。執行結果如下：

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel(' y axis caption ')
plt.show()

# %% [markdown]
# 折線圖最重要的是根據xy座標繪圖,繪圖之前一般會將在xy座標存入串列值。
# 其中y座標的串列值是必須的,座標值若不在時會自動產生由開始的等距串列,
# 例如繪製6個點:

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]

plt.plot(listx,listy)
plt.show()

# %% [markdown]
# ## 1-2. 指定繪圖樣式

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color='r', lw='2.0', ls='-.',marker="h",ms=12)  #color顏色；lw線寬；markerr節點型態；ms節點大小
plt.show()

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color='g', lw='2.0', ls='--',marker="*",ms=12)  #color顏色；lw線寬；markerr節點型態；ms節點大小
plt.show()

# %% [markdown]
# ### ****** color & linestyle & maker 組合字串，這三個設定可以直接合併設定。******

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, 'g--*', lw='2.0',ms=12)  #color顏色；lw線寬；markerr節點型態；ms節點大小
plt.show()

# %% [markdown]
# ### ****** 設定圖例名稱 - lable，label='label' 需要搭配 legend 函數才有效果******

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color='red', lw='2.0', ls='--', label='label')
plt.legend()
plt.show()

# %% [markdown]
# ## 1-3. 設定標題

# %% [markdown]
# 設定圖表標題、X及Y座標標題的語法如下，如果不設定 fontsize，大小會一樣:

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color="red", lw="2.0", ls="--", label="label")

plt.title("Chart Title", fontsize=20)	#圖表標題
plt.xlabel("X-Label", fontsize=14)		#x座標標題
plt.ylabel("Y-Label", fontsize=14)		#y座標標題

plt.legend()
plt.show()

# %% [markdown]
# ## 1-4. 指定座標範圍

# %% [markdown]
# 如果沒有指定X及Y座標範圍，系統會根據資料判斷最適合的座標範圍。設計者可以自行設定X及Y座標範圍，語法為:

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color="red", lw="2.0", ls="--", label="label")

plt.title("Chart Title")	#圖表標題
plt.xlabel("X-Label")		#x座標標題
plt.ylabel("Y-Label")		#y座標標題

plt.xlim(0, 20)            #設定x座標範圍
plt.ylim(0, 100)             #設定y座標範圍

plt.legend()
plt.show()

# %% [markdown]
# ## 1-5. 指定座標刻度

# %% [markdown]
# 在以下的圖表中，X座標範圍為0到5000，在預設的狀態下Matplotlib自動以1000為間距加上了刻度。若想自訂座標刻度，語法如下:

# %%
import matplotlib.pyplot as plt

listx = [0,800,1500,3200,4100,5000]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy)

plt.show()

# %% [markdown]
# ### ******可以設定成範圍0~5000，以500為間距，字型10點，刻度為紅色。******

# %%
import matplotlib.pyplot as plt

listx = [0,800,1500,3200,4100,5000]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy)

plt.xticks(range(0,5500,500))
plt.tick_params(axis='both', labelsize=10, color='red')

plt.show()

# %% [markdown]
# ## 1-6. 設定格線

# %% [markdown]
# 為圖表加上格線的語法如下:

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color="red", lw="2.0", ls="--", label="label")
plt.title("Chart Title")    #圖表標題
plt.xlabel("X-Label")       #x座標標題
plt.ylabel("Y-Label")       #y座標標題
plt.xlim(0, 20)             #設定x座標範圍
plt.ylim(0, 100)            #設定y座標範圍

plt.grid(True)              #設定格線

plt.legend()
plt.show()

# %% [markdown]
# 也可以進一步設定格線顏色，寬度、樣式以及透明度，例如:

# %%
import matplotlib.pyplot as plt

listx = [0,5,7,12,18,20]
listy = [20,60,32,45,78,56]
plt.plot(listx, listy, color="red", lw="2.0", ls="--", label="label")
plt.title("Chart Title")    #圖表標題
plt.xlabel("X-Label")       #x座標標題
plt.ylabel("Y-Label")       #y座標標題
plt.xlim(0, 20)             #設定x座標範圍
plt.ylim(0, 100)            #設定y座標範圍

plt.grid(color='blue', linestyle=":", linewidth='2', alpha=0.5)    #設定格線顏色，寬度、樣式以及透明度

plt.legend()
plt.show()

# %% [markdown]
# ## 1-7. 同時繪製多組資料

# %% [markdown]
# 一個圖表中可以繪製多組資料的線條，如果沒有設定線條顏色，系統會自行設定不同的顏色進行繪圖，例如:

# %%
# plot6.py
import matplotlib.pyplot as plt

listx1 = [1,5,7,9,13,16]
listy1 = [15,50,80,40,70,50]
plt.plot(listx1, listy1, '-.s')
listx2 = [2,6,8,11,14,16]
listy2 = [10,40,30,50,80,60]
plt.plot(listx2, listy2, '-s')
plt.show()

# %%
# plot6.py
import matplotlib.pyplot as plt

listx1 = [1,5,7,9,13,16]
listy1 = [15,50,80,40,70,50]
plt.plot(listx1, listy1, 'r-.s')   #設定紅色
listx2 = [2,6,8,11,14,16]
listy2 = [10,40,30,50,80,60]
plt.plot(listx2, listy2, 'b-s')    #設定藍色
plt.show()

# %% [markdown]
# 其實多組數據可以一起繪圖，因為每個線條的數據、樣式都不同，其語法如下:

# %%
import matplotlib.pyplot as plt

year = [2016,2017,2018,2019,2020]
city1 = [100,180,90,220,150]
plt.plot(year, city1, 'r-.s', lw=2, ms=10, label="Taipei")

city2 = [160,50,120,140,110]
plt.plot(year, city2, 'g--*', lw=2, ms=10, label="Kaohsiung")
plt.legend()

plt.ylim(0, 250)
plt.xticks(year)
plt.title("Sales Report", fontsize=18)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Million", fontsize=12)
plt.grid(color='k', ls=':', lw=1, alpha=0.5)
plt.show()

# %% [markdown]
# ## 2. 繪製長條圖 : bar、barh

# %% [markdown]
# ## 2-1. 繪製直條圖

# %% [markdown]
# 直條圖是以bar函數繪製 :

# %% [markdown]
# 繪圖時除了xy座標串列參數之外,呈現每個項目的矩形是重點,常用參數有 :

# %% [markdown]
# + width : 設定每個項目矩形的寬度。以二個刻度之間的距離為基準,用百分比為單位來設定。不設定時預設值為 0.8。
#
# + bottom : 設定每個項目矩形y座標的起始位置,不設定時預設值為。
#
# + color : 設定每個項目矩形的顏色,設定值與折線圖相同,預設為藍色。例如設定紅色可以為"r"或"red"。如果設定值為"rgb”代表會以紅、綠、藍依序循環顯示每個項目矩形的顏色。
#
# + label:設定毎個項目圖例名稱,此屬性需搭配legend函數才有效果。

# %%
import matplotlib.pyplot as plt

listx = ['c','c++','c#','java','python']
listy = [45,28,38,32,50]

plt.bar(listx, listy, width=0.5, color='rgb')

plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")

# 設定中文字型及負號正確顯示
plt.rcParams["font.sans-serif"] = "Microsoft JhengHei" 
plt.rcParams["axes.unicode_minus"] = False
plt.show()

# %% [markdown]
# ## 2-2. 繪製橫條圖

# %% [markdown]
# 橫條圖是以barh函數繪製 :

# %% [markdown]
# 橫條圖基本上與長條圖相似,但因為方向不同,所有參數就必須倒過來。
#
# 繪圖時除了設定矩形樣式的參數與長條圖相同外,還需特別注意:

# %% [markdown]
# + y座標串列 : 顯示每個項目的名稱串列或是序列串列。
#
# + x座標串列 : 顯示每個項目的數值串列。
#
# + height : 設定每個項目矩形的高度。以二個刻度之間的距離為基準,用百分比為單位來設定。不設定時預設值為0.8。
#
# + left : 設定每個項目矩形x座標的起始位置,不設定時預設值為0。

# %%
import matplotlib.pyplot as plt

listy = ['c','c++','c#','java','python']
listx = [45,28,38,32,50]

plt.barh(listy, listx, height=0.5, color='rgb')

plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")

# 設定中文字型及負號正確顯示
plt.rcParams["font.sans-serif"] = "Microsoft JhengHei" 
plt.rcParams["axes.unicode_minus"] = False
plt.show()

# %% [markdown]
# ## 2-3. 繪製堆疊長條圖

# %% [markdown]
# 當資料中的每個項目都還能分出子項目時,可以在繪製長條圖用堆疊的方式，在每個項目的矩形中顯示出每個子項目的比重。
#
# 這時就必須要應用到bottom屬性,完成第一組長條圖後，在繪製第二組長條圖時，可將y軸的起點設定為第一組資料的y軸高度。

# %%
import matplotlib.pyplot as plt

listx = ['c','c++','c#','java','python']
listy1 = [25,20,20,16,28]
listy2 = [20,8,18,16,22]

plt.bar(listx, listy1, width=0.5, label='男')                  ###
plt.bar(listx, listy2, width=0.5, bottom=listy1, label='女')   ###

plt.legend()

plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")

# 設定中文字型及負號正確顯示
plt.rcParams["font.sans-serif"] = "Microsoft JhengHei" 
plt.rcParams["axes.unicode_minus"] = False
plt.show()

# %% [markdown]
# 繪製第一組資料時,並没有設定bttom·所以預設由y座標為0處由下往上繪製。
#
# 而第二組資料時,因為要接著第一組資料結束處,所以起始點bottom必須為第一組資料的高度,才能讓二組資料完美堆疊顯示。

# %% [markdown]
# ## 2-4. 繪製並列長條圖

# %% [markdown]
# 長條圖的資料會在每個項目用並列的方式呈現多個子項目,即能很快的在每個項取中檢視每個子項目數目的大小。
#
# 長條圖每個x座標的刻度間距是相等的,當繪製每個項目的矩形時,預設會以刻度為寬度的中心點,但分成多個子項目時就會交疊在一起。所以每個項目中子項目在
# 刻度上的起始位置就很重要。

# %%
import matplotlib.pyplot as plt

width = 0.25                                              ###設定每個項目的寬度(再由子項目分)
listx = ['c','c++','c#','java','python']

listx1 = [x - width/2 for x in range(len(listx))]         ###EX1
listx2 = [x + width/2 for x in range(len(listx))]         ###EX2

listy1 = [25,20,20,16,28]
listy2 = [20,8,18,16,22]

plt.bar(listx1, listy1, width, label='男')
plt.bar(listx2, listy2, width, label='女')

plt.xticks(range(len(listx)), labels=listx)     ####EX3
   
plt.legend()
plt.title("資訊程式課程選修人數")
plt.xlabel("程式課程")
plt.ylabel("選修人數")
# 設定中文字型及負號正確顯示
plt.rcParams["font.sans-serif"] = "Microsoft JhengHei" 
plt.rcParams["axes.unicode_minus"] = False
plt.show()

# %% [markdown]
# + EX1：設定第一組子項目的串列:「男」在x座標刻度出現位置。基本上這個串序會以項目序列當作預設值。但在範例中有二組子項目,所以這個子項目要向左移動「項目寬度/2」的距離,才不會與第二組子項目交疊。這裡使用串列綜合表達式的函數將子項目串列中的值逐一進行向左移動的運算。

# %% [markdown]
# + EX2：設定第二組子項目的串列:「女」在x座標刻度出現位置,這個子項目要向右移動「項目寬度/2」的距離,才不會與第一組子項目交疊。

# %% [markdown]
# + EX3：在並列長條圖x刻度的標籤,因為有子項目,所以會以項目的序列等距來顯示。但範例是希望能呈現文字型態的程式名稱,所以利用 xticks() 的函數設定用項目串列來取代顯示。

# %% [markdown]
# ## 3. 繪製散佈圖 : Scatter

# %% [markdown]
# 散怖圖是以scatter函數繪製。
#
#
# xy是數值串列,為必要參數。其他常用的參數有:

# %% [markdown]
# + s : 大小尺寸數值組成的串列。
#
# + c : 顏色字元組成字串或是串列。
#
# + m : 標記樣式字串，預設為'o'。
#
# + alpha : 透明度，數值範圍在0~1之間。

# %% [markdown]
# 在範例中將要用散怖圖來表現數值分布狀況:

# %%
import matplotlib.pyplot as plt

listx = [31,15,20,25,12,18,45,21,33,5,18,22,37,42,10]
listy = [68,20,61,32,45,56,10,18,70,64,43,66,19,77,21]
scale = [x**3 for x in [5,4,2,6,7,1,8,9,2,3,2,4,5,7,2]]

plt.xlim(0,50)
plt.ylim(0,80)
plt.scatter(listx, listy, c='r', s=scale, marker='o', alpha=0.5)

plt.show()

# %% [markdown]
# ## 4. 繪製圓餅圖 : pie

# %% [markdown]
# 圓餅圖是以pie函數繪製。
#
# 資料串列是數值串列,為必要參數。其他常用的參數有:

# %% [markdown]
# + labels : 每一個項目標題組成的串列。
#
# + colors : 每一個項目顏色字元組成的字串或是串列,如'rgb'或 ['r','g','b']。
#
# + explode:每一個項目凸出距離數字組成的串列,「0」表示正常顯示。
#
# + labeldistance : 項目標題與圓心的距離是半徑的多少倍,例如「1.1」表示項目標題與圓心的距離是半徑的1.1倍。
#
# + autopct : 項目百分比的格式,語法為「%格式%%」,例如「%2.1f%%」表示整數2位數，小數1位數。
#
# + pctdistance : 百分比文字與圓心的距離是半徑的多少倍。
#
# + shadow : 布林值，True表示圖形有陰影,False表示圖形沒有陰影。
#
# + startangle : 開始繪圖的起始角度,繪圖會以逆時針旋轉計算角度。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

sizes = [25, 30, 15, 10]
labels = ["北部", "西部", "南部", "東部"]
colors = ["red", "green", "blue", "yellow"]
explode = (0, 0, 0.2, 0)            ##凸出距離數值串列，第三部分，數值 0.2
plt.pie(sizes, 
	explode = explode, 
	labels = labels, 
	colors = colors,
	labeldistance = 1.1, 
	autopct = "%2.1f%%", 
	pctdistance = 0.6,
	shadow = True,
	startangle = 90)

# 設定中文字型及負號正確顯示
plt.rcParams["font.sans-serif"] = "Microsoft JhengHei" 
plt.rcParams["axes.unicode_minus"] = False
plt.show()

# %% [markdown]
# ### ******園的展示效果很好,但僅適合少量資料呈現,若將圓餅圖分割成太多塊,比例太低無法看清楚資料。******

# %% [markdown]
# ## 5. 設定圖表區 : figure

# %% [markdown]
# 當繪製折線圖、長條圖或圓餅圖時，Matplotlib.pyplot會自動產生圖表區，再於其中繪製圖表。因為沒有特別的設定,圖表區都會以預設的大小、解析度、顏
# 來佈置圖表區。
#
# 圖表區是以figure類別來建立。
#
# 如果沒有設定參數則會以預設值建立圖表區,以下為常用的參數:

# %% [markdown]
# + figsize : 設定方式為串列:[寬,高】,單位為英时,預設值為[6.4,4.8]。
#
# + dip : 設定解析度,單位為每英吋的點數(Dotsperinch)。
#
# + facecolor : 設定背景顏色,預設值為白色(white)。
#
# + edgecolor : 設定邊線顏色,預設值為白色(white)。
#
# + frameon : 布林值,設定是否有邊框,預設值為True。
#
# + tight_layout : 布林值，設定多個圖表間是否有邊界,預設值為False

# %% [markdown]
# 以下新增二個圖表區，一個用預設值，一個自訂屬性:

# %%
import matplotlib.pyplot as plt

# 新增圖表區
plt.figure()
plt.plot([1,2,3])

# 新增圖表區並設定屬性
plt.figure(figsize=[8,4], dpi=84, facecolor="whitesmoke", edgecolor="r", linewidth=1, frameon=True)
plt.plot([1,2,3])

plt.show()

# %% [markdown]
# 可以在結果中看到，雖然在二個圖表區中所繪製的圖表與數據都相同,但有設定顯示屬性的就比使用預設值的明顯許多。

# %% [markdown]
# ## 6. 在圖表區加入多張圖表 : subplot、axes

# %% [markdown]
# ## 6-1. 用欄列排列多張圖表 : subplot

# %% [markdown]
# subplot()函數則是可以讓我們在一張大圖的範圍中繪製多個小的子圖。subplot()中的參數一般有3個，分別為橫列數，直欄數，以及子圖序號。例如：

# %% [markdown]
# ### ******例如要在圖表區加入2列1欄的二張圖表:******

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,8])

plt.subplot(211)              #序號 1
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.subplot(212)              #序號 2
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')

plt.show()

# %% [markdown]
# ### ******例如要在圖表區加入1列2欄的二張圖表:******

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,8])

plt.subplot(121)              #序號 1
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.subplot(122)              #序號 2
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')

plt.show()

# %% [markdown]
# ### ******再多張的圖表也没問題,例如要在圖表區加入2列2欄的四張圖表:******

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,8])

plt.subplot(221)
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.subplot(222)
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')

plt.subplot(223)
plt.title(label='Chart 3')
plt.plot([1,2,3],'b:o')

plt.subplot(224)
plt.title(label='Chart 4')
plt.plot([1,2,3],'y--o')

plt.show()

# %% [markdown]
# ## 6-2. 用相對位置排列多張圖表 : axes

# %% [markdown]
# 在圖表區用相對位置的方式加入多張圖表可以使用axes函數。

# %% [markdown]
# axes是以圖表區的左下角為原點，前二個數字分别是離左方與下方的邊界距離，後二個數字是這個圖表的寬高。而這4個數值都是以圖表區的寬高為基準,用0到1之間的浮點數做為計算,例如圖表的寬度是圖表區的一半,值為0.5。
#
# 例如要在圖表區加入二張左右排列的圖表:。

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,4])

plt.axes([0,0,0.4,1])           ###plt.axes([與左邊界距離, 與下邊界距離 ,寬 ,高])
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.axes([0.5,0,0.4,1])
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')

plt.show()

# %% [markdown]
# 因為 axes是用相對位置來加入圖表,在設定上不會有相互排擠的狀況出現。而且圖表之間可以彼此交疊,所以能發揮更多的彈性。
#
# 例如想要在圖表區加入子母圖表:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=[8,4])

plt.axes([0,0,0.8,1])
plt.title(label='Chart 1')
plt.plot([1,2,3],'r:o')

plt.axes([0.55,0.1,0.2,0.2])
plt.title(label='Chart 2')
plt.plot([1,2,3],'g--o')

plt.show()

# %% [markdown]
# ## Homework #1

# %% [markdown]
# 在這個專題中以圖書分類的銷售資料在一個圖表區中分別繪製男性、女性銷售率圓餅圖、長條圖及折線圖。
#
# 以下是某圖書公司,各分類的男女性銷售資料:
#
# 接著想要利用這些資料在同一個圖表區分別分析:
#
# 1.書分類男性銷售比率-圓餅
#
# 2.書分類女性銷售比率-圓餅圖
#
# 3.書分類男女性銷售-長條圖
#
# 4.圖書分類男女性銷售-折線圖

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
